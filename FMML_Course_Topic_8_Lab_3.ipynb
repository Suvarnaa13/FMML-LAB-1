# %% [markdown]
# <a href="https://colab.research.google.com/github/Suvarnaa13/FMML-LAB-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-30 14:46:25--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  89.8MB/s    in 0.8s
#
# 2024-03-30 14:46:26 (89.8 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 2603 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 1745 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 14331  cs/9809027v1  Much of the power of probabilistic methods in ...    cs
# 18470   1012.1646v1  ChemgaPedia is a multimedia, webbased eLearnin...    cs
# 2986   1511.06380v2  The ability to predict future states of the en...    cs
# 343    1703.02000v7  Class labels have been empirically shown usefu...    cs
# 27186  1702.07019v1  Increasing use of CT in modern medical practic...    cs
# ...             ...                                                ...   ...
# 26779  1611.08588v2  In object detection, reducing computational co...    cs
# 15872  1606.03622v1  Modeling crisp logical regularities is crucial...    cs
# 5199    1111.6201v4  We consider the problem of learning a linear f...    cs
# 4739   1612.05299v1  With the resurgence of interest in neural netw...    cs
# 11929  1704.03453v2  Adversarial examples are maliciously perturbed...  stat
#
#                                                    title  year  \
# 14331  Conditions on Consistency of Probabilistic Tre...  1998
# 18470  Use of semantic technologies for the developme...  2010
# 2986   Unsupervised Learning of Visual Structure usin...  2015
# 343    Activation Maximization Generative Adversarial...  2017
# 27186  CT Image Denoising with Perceptive Deep Neural...  2017
# ...                                                  ...   ...
# 26779  PVANet: Lightweight Deep Neural Networks for R...  2016
# 15872     Data Recombination for Neural Semantic Parsing  2016
# 5199         Learning a Factor Model via Regularized PCA  2011
# 4739   A Survey of Inductive Biases for Factorial Rep...  2016
# 11929     The Space of Transferable Adversarial Examples  2017
#
#                                                 keywords
# 14331  [probabilistic, modelling, derivations, import...
# 18470  [chemgapedia, multimedia, elearning, currently...
# 2986   [environment, intelligence, effective, predict...
# 343    [empirically, improving, generative, adversari...
# 27186  [increasing, associated, radiation, reduction,...
# ...                                                  ...
# 26779  [detection, computational, important, improvin...
# 15872  [regularities, difficult, knowledge, introduce...
# 5199   [regularized, principal, component, demonstrat...
# 4739   [resurgence, representation, artificial, intel...
# 11929  [adversarial, maliciously, perturbed, adversar...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 14331    [probabilistic, modelling, derivations, import...
# 18470    [chemgapedia, multimedia, elearning, currently...
# 2986     [environment, intelligence, effective, predict...
# 343      [empirically, improving, generative, adversari...
# 27186    [increasing, associated, radiation, reduction,...
#                                ...
# 1560     [superpivot, languages, superparallel, magnitu...
# 21725    [applications, decomposition, component, funct...
# 13096    [parameter, estimation, asymptotic, inference,...
# 21694    [estimating, undirected, dimensional, assumpti...
# 16435    [systematic, theoretical, empirical, compariso...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8760 words.
# Out of those 4588 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b4abbcbe-a1ed-4b4a-9539-ce4f49e51e4a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4abbcbe-a1ed-4b4a-9539-ce4f49e51e4a")) {                    Plotly.newPlot(                        "b4abbcbe-a1ed-4b4a-9539-ce4f49e51e4a",                        [{"x":["probabilistic","consistency","consistent","probabilities","conditions","algorithm","deficiency","modelling","properties","probability","derivations","justification","important","correctness","precisely","literature","technologies","representation","organized","scientific","educational","generator","multimedia","trajectories","generating","experiments","frequently","currently","development","chemistry","unsupervised","naturally","themselves","predictive","reconstruction","sequences","intelligence","underlying","environment","classification","structure","synthetic","transformations","effective","prediction","dimensional","importantly","predicting","understanding","architecture","developed","information","furthermore","effectively","rotations","generalize","generated","successfully","representations","performance","including","adversarial","excellent","generative","generalizes","framework","demonstrate","inception","influence","empirically","maximization","associated","effectiveness","decomposition","outperforms","baselines","conducted","diversity","improving","activation","estimation","classifier","mathematically","comprehensive","adversely","correspond","computing","different","therefore","diagnostic","radiation","confidence","similarity","minimizing","impressive","reduction","introduce","challenging","techniques","structural","artifacts","popularized","direction","perceptual","perceptive","smoothing","intensity","convolutional","facilitate","increasing","approaches","denoising","promising","objective","developments","forefront","theoretical","grounding","sentiment","difficulty","approximate","interpretation","knowledge","inference","theoretically","application","technique","recurrent","variational","assessing","extension","intersection","convergence","computation","convexity","observations","introduced","initializing","optimization","independent","stochastic","algorithms","initialization","iteration","significantly","conventional","proceedings","implications","conceptual","international","evolutionary","implementations","distributed","environments","conference","investigate","modification","iterations","suboptimal","optimality","averaging","experimental","returning","necessary","dimensionality","assumption","primarily","streaming","challenge","complexity","scenarios","manifolds","smoothness","irregularly","computational","practical","situations","potentially","continuity","intersecting","dirichlet","experiment","analogies","corresponding","hypergraph","normalized","outperform","laplacian","differential","supervised","relational","processing","connections","formalize","generalization","laplacians","hypergraphs","simplified","existence","minimized"],"y":[145,70,83,58,137,779,7,61,218,182,6,9,370,19,21,134,35,363,18,30,1,36,12,31,98,628,26,63,130,5,138,62,28,63,105,109,79,112,122,529,328,136,35,257,217,158,27,83,147,231,225,689,141,123,10,63,183,83,252,833,245,103,34,131,31,539,559,10,57,85,27,112,232,63,251,52,79,39,113,29,212,146,12,55,4,24,137,738,154,31,6,44,150,53,23,87,338,268,351,75,29,3,60,25,2,23,34,370,39,105,473,38,103,164,18,2,163,10,53,43,108,59,356,184,38,240,251,155,65,20,81,15,119,130,8,70,142,4,295,129,130,610,31,45,295,110,12,16,23,11,58,30,95,93,14,146,19,27,17,18,22,399,2,84,60,57,18,15,165,221,89,27,19,3,273,146,47,58,11,4,19,66,7,118,2,26,72,11,34,211,29,290,48,18,103,1,0,28,43,11],"type":"bar"},{"x":["probabilistic","consistency","consistent","pro ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4588,), (4588, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8033333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Combine</span> <span style=''>CRF</span> <span style=''>and</span> <span style=''>MMSEG</span> <span style=''>to</span> <span style=''>Boost</span> <span style=''>Chinese</span> <span style=''>Word</span> <span style='background-color:rgba(0, 255, 0, 0.7510373443983402);'>Segmentation</span> <span style=''>in</span> <span style=''>Social</span> <span style=''>Media</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>the</span> <span style=''>word</span> <span style='background-color:rgba(0, 255, 0, 0.7510373443983402);'>segmentation</span> <span style=''>on</span> <span style=''>Chinese</span> <span style=''>social</span> <span style=''>media</span> <span style=''>Previous</span> <span style=''>work</span> <span style=''>mainly</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>word</span> <span style='background-color:rgba(0, 255, 0, 0.7510373443983402);'>segmentation</span> <span style=''>for</span> <span style=''>plain</span> <span style=''>Chinese</span> <span style=''>text</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>Chinese</span> <span style=''>social</span> <span style=''>media</span> <span style='background-color:rgba(0, 255, 0, 0.4463840399002494);'>processing</span> <span style=''>tool</span> <span style=''>we</span> <span style=''>need</span> <span style=''>to</span> <span style=''>take</span> <span style=''>the</span> <span style=''>main</span> <span style=''>features</span> <span style=''>of</span> <span style=''>social</span> <span style=''>media</span> <span style=''>into</span> <span style=''>account</span> <span style=''>whose</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>grammatical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>is</span> <span style=''>not</span> <span style=''>rigorous</span> <span style=''>and</span> <span style=''>the</span> <span style=''>tendency</span> <span style=''>of</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>colloquial</span> <span style=''>and</span> <span style=''>Internet</span> <span style=''>terms</span> <span style=''>makes</span> <span style=''>the</span> <span style=''>existing</span> <span style=''>Chinese</span> <span style='background-color:rgba(0, 255, 0, 0.4463840399002494);'>processing</span> <span style=''>tools</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>inefficient</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>on</span> <span style=''>social</span> <span style=''>media</span> <span style=''>In</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>we</span> <span style=''>combine</span> <span style=''>CRF</span> <span style=''>and</span> <span style=''>MMSEG</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>extend</span> <span style=''>features</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3433962264150943);'>traditional</span> <span style=''>CRF</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>train</span> <span style=''>the</span> <span style=''>model</span> <span style=''>for</span> <span style=''>word</span> <span style='background-color:rgba(0, 255, 0, 0.7510373443983402);'>segmentation</span> <span style=''>We</span> <span style=''>use</span> <span style=''>Internet</span> <span style=''>lexicon</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Instrumental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variables</span> <span style=''>with</span> <span style=''>Non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Gaussianity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Assumptions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Limitations</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Practical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithms</span> <br/><br/><span style=''>Learning</span> <span style=''>a</span> <span style=''>causal</span> <span style=''>effect</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observational</span> <span style=''>data</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>straightforward</span> <span style=''>as</span> <span style=''>this</span> <span style=''>is</span> <span style=''>not</span> <span style=''>possible</span> <span style=''>without</span> <span style=''>further</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>If</span> <span style=''>hidden</span> <span style=''>common</span> <span style=''>causes</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>X</span> <span style=''>and</span> <span style=''>outcome</span> <span style=''>Y</span> <span style=''>cannot</span> <span style=''>be</span> <span style=''>blocked</span> <span style=''>by</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>one</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>possibility</span> <span style=''>is</span> <span style=''>to</span> <span style=''>use</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>instrumental</span> <span style=''>variable</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>it</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>under</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>to</span> <span style=''>discover</span> <span style=''>whether</span> <span style=''>a</span> <span style=''>variable</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structurally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>instrumental</span> <span style=''>to</span> <span style=''>a</span> <span style=''>target</span> <span style=''>causal</span> <span style=''>effect</span> <span style=''>X</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>rightarrow</span> <span style=''>Y</span> <span style=''>but</span> <span style=''>current</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frameworks</span> <span style=''>are</span> <span style=''>somewhat</span> <span style=''>lacking</span> <span style=''>on</span> <span style=''>how</span> <span style=''>general</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>can</span> <span style=''>be</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>instrumental</span> <span style=''>variable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discovery</span> <span style=''>problem</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>as</span> <span style=''>no</span> <span style=''>variable</span> <span style=''>can</span> <span style=''>be</span> <span style=''>tested</span> <span style=''>as</span> <span style=''>an< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.42857142857142855);'>Distributionally</span> <span style=''>Robust</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Submodular</span> <span style='background-color:rgba(255, 0, 0, 0.42553191489361697);'>Maximization</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Submodular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>throughout</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>but</span> <span style=''>in</span> <span style=''>many</span> <span style=''>settings</span> <span style=''>we</span> <span style=''>do</span> <span style=''>not</span> <span style=''>have</span> <span style=''>direct</span> <span style=''>access</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>function</span> <span style=''>f</span> <span style=''>We</span> <span style=''>focus</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.35162094763092266);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>that</span> <span style=''>are</span> <span style=''>given</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.40425531914893614);'>expectation</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>over</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>P</span> <span style=''>In</span> <span style=''>practice</span> <span style=''>we</span> <span style=''>often</span> <span style=''>have</span> <span style=''>only</span> <span style=''>a</span> <span style=''>limited</span> <span style=''>set</span> <span style=''>of</span> <span style=''>samples</span> <span style=''>f</span> <span style=''>i</span> <span style=''>from</span> <span style=''>P</span> <span style=''>The</span> <span style=''>standard</span> <span style=''>approach</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>indirectly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizes</span> <span style=''>f</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximizing</span> <span style=''>the</span> <span style=''>sum</span> <span style=''>of</span> <span style=''>f</span> <span style=''>i</span> <span style=''>However</span> <span style=''>this</span> <span style=''>ignores</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>to</span> <span style=''>the</span> <span style=''>true</span> <span style=''>(unknown)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>achieve</span> <span style=''>better</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>on</span> <span style=''>the</span> <span style=''>actual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>function</span> <span style=''>f</span> <span style=''>by</span> <span style=''>directly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizing</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3484162895927602);'>combination</span> <span style=''>of</span> <span style=''>bias</span> <span style=''>and</span> <span style=''>variance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithmically</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.375);'>accomplish</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Neural</span> <span style=''>Networks</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Compression</span> <span style=''>for</span> <span style=''>Language</span> <span style=''>Modeling</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compression</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>for</span> <span style=''>the</span> <span style=''>language</span> <span style=''>modeling</span> <span style=''>problem</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(RNNs)</span> <span style=''>It</span> <span style=''>is</span> <span style=''>known</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conventional</span> <span style=''>RNNs</span> <span style=''>eg</span> <span style=''>LSTM</span> <span style=''>based</span> <span style=''>networks</span> <span style=''>in</span> <span style=''>language</span> <span style=''>modeling</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterized</span> <span style=''>with</span> <span style=''>either</span> <span style=''>high</span> <span style=''>space</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>substantial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>time</span> <span style=''>This</span> <span style=''>problem</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style=''>crucial</span> <span style=''>for</span> <span style=''>mobile</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style=''>constant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interaction</span> <span style=''>with</span> <span style=''>the</span> <span style=''>remote</span> <span style=''>server</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inappropriate</span> <span style=''>By</span> <span style=''>using</span> <span style=''>the</span> <span style=''>Penn</span> <span style=''>Treebank</span> <span style=''>(PTB)</span> <span style=''>dataset</span> <span style=''>we</span> <span style=''>compare</span> <span style=''>pruning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantization</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style=''>tensor</span> <span style=''>train</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>for</span> <span style=''>LSTM</span> <span style=''>networks</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>model</span> <span style=''>size</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>suitability</span> <span style=''>for</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.13006091006807596)
# 	processing (0.10390541024722322)
# 	knowledge (0.12755284844141884)
# 	segmentation (0.07560014331780723)
# 	experimental (0.1429595127194554)
# 	information (0.2468649229666786)
# 	detection (0.12002866356144751)
# 	different (0.2644213543532784)
# 	convolutional (0.13256897169473308)
# 	recognition (0.13185238265854532)
#
# Some Statistics words are:
# 	theoretical (0.1448481831757093)
# 	statistical (0.14733698357391736)
# 	stochastic (0.13489298158287705)
# 	variables (0.14235938277750124)
# 	estimation (0.18118466898954705)
# 	distribution (0.1836734693877551)
# 	algorithm (0.38974614235938276)
# 	inference (0.1836734693877551)
# 	regression (0.17322050771528125)
# 	dimensional (0.19611747137879543)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f9a0e8d7-97c4-4bc8-8735-206356db2fe8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9a0e8d7-97c4-4bc8-8735-206356db2fe8")) {                    Plotly.newPlot(                        "f9a0e8d7-97c4-4bc8-8735-206356db2fe8",                        [{"x":["probabilistic","consistency","consistent","probabilities","conditions","algorithm","deficiency","modelling","properties","probability","derivations","justification","important","correctness","precisely","literature","technologies","representation","organized","scientific","educational","generator","multimedia","trajectories","generating","experiments","frequently","currently","development","chemistry","unsupervised","naturally","themselves","predictive","reconstruction","sequences","intelligence","underlying","environment","classification","structure","synthetic","transformations","effective","prediction","dimensional","importantly","predicting","understanding","architecture","developed","information","furthermore","effectively","rotations","generalize","generated","successfully","representations","performance","including","adversarial","excellent","generative","generalizes","framework","demonstrate","inception","influence","empirically","maximization","associated","effectiveness","decomposition","outperforms","baselines","conducted","diversity","improving","activation","estimation","classifier","mathematically","comprehensive","adversely","correspond","computing","different","therefore","diagnostic","radiation","confidence","similarity","minimizing","impressive","reduction","introduce","challenging","techniques","structural","artifacts","popularized","direction","perceptual","perceptive","smoothing","intensity","convolutional","facilitate","increasing","approaches","denoising","promising","objective","developments","forefront","theoretical","grounding","sentiment","difficulty","approximate","interpretation","knowledge","inference","theoretically","application","technique","recurrent","variational","assessing","extension","intersection","convergence","computation","convexity","observations","introduced","initializing","optimization","independent","stochastic","algorithms","initialization","iteration","significantly","conventional","proceedings","implications","conceptual","international","evolutionary","implementations","distributed","environments","conference","investigate","modification","iterations","suboptimal","optimality","averaging","experimental","returning","necessary","dimensionality","assumption","primarily","streaming","challenge","complexity","scenarios","manifolds","smoothness","irregularly","computational","practical","situations","potentially","continuity","intersecting","dirichlet","experiment","analogies","corresponding","hypergraph","normalized","outperform","laplacian","differential","supervised","relational","processing","connections","formalize","generalization","laplacians","hypergraphs","simplified","existence","minimized","specified","considering","applications","constraint","redundancy","interested","distillation","feasibility","potential","sensitivity","advantageous","empirical","quickscore","applicable","determinism","likelihood","compilation","exploiting","computations","compiling","detection","plagiarism","considered","detecting","flowcharts","flowchart","advantage","according","retrieval","phenomenon","discarding","imputation","represented","alleviating","comparable","measurements","variables","characterized","undergoing","collected","completely","multivariate","similarities","complicate","infection","colorectal","identifying","electronic","outperformed","reference","parameters","overfitting","imitation","benchmark","estimators","predic ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	hypergraphs
# 	unequally
# 	judiciously
# 	impressively
# 	unconditional
# 	geostatistical
# 	questionnaires
# 	submodularity
# 	preconditioned
# 	concavity
# 	oscillates
# 	fmathcalx
# 	discretizations
# 	trilinear
# 	stragglers
# 	straggler
# 	procrustes
# 	wirtinger
# 	nonstationary
# 	groundwork
# Some words which never appear in Statistics papers:
# 	deficiency
# 	perceptive
# 	quickscore
# 	determinism
# 	compilation
# 	compiling
# 	plagiarism
# 	flowcharts
# 	flowchart
# 	utterances
# 	justifications
# 	canonically
# 	sadrzadeh
# 	panchromatic
# 	fascinating
# 	dominating
# 	atmosphere
# 	evaluators
# 	australia
# 	fantastic

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.077112437688473e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7625
